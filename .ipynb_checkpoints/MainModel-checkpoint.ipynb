# %% [markdown]
# # Forcasting Price Change on IPO-day

# %% [markdown]
# ### Author：Joy Zhou

# %% [markdown]
# ### Overview

# %% [markdown]
# - [1、Background](#1、Background)
# - [2、Functions Define](#2、Functions-Define)
# - [3、Data Preprocessing](#3、Data-Preprocessing)
#     - [3.1 Deal with nominal and ordinal features](#3.1-Deal-with-nominal-and-ordinal-features)
#     - [3.2 Assessing feature importance with Random Forests](#3.2-Assessing-feature-importance-with-Random-Forests)
# - [4、ML Model](#4、ML-Model)
#     - [4.1 Linear Regression](#4.1-Linear-Regression)
#     - [4.2 Decision Tree](#4.2-Decision-Tree)
#     - [4.3 Random Forest](#4.3-Random-Forest)
#     - [4.4 Logistic Regression](#4.4-Logistic-Regression)
#     - [4.5 KNN](#4.5-KNN)
#     - [4.6 SVM](#4.6-SVM)
#     - [4.7 Multi-layer Perceptron](#4.7-Multi--layer-Perceptron)
# - [5、Summary](#5、Summary)
#     - [5.1 The relationship about the features and dependent variable](#5.1-The-relationship-about-the-features-and-dependent-variable)
#     - [5.2 The forecasting result of the ML model](#5.2-The-forecasting-result-of-the-ML-model)

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# ## 1、Background

# %%
from IPython.display import Image
Image(filename='./images/ipoprocess.png', width=500)

# %%
Image(filename='./images/iporeturn.png', width=500)

# %% [markdown]
# After 2014,there was a policy that the return on the ipo day cannot beyond 44%.
#
# Then, it is common to see the stock price have continuous 10% growth for several days.
#
# Thus,for those stocks ipo after 2014,we use the return for 10 days instead.

# %%
Image(filename='./images/policychange.png', width=600)

# %%
Image(filename='./images/x&y.png', width=600)

# %% [markdown]
# <br>

# %% [markdown]
# # 2、Functions Define

# %%
import datetime
import numpy as np
import pandas as pd
import time
from __future__ import division
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.cross_validation import train_test_split
from sklearn.linear_model.logistic import LogisticRegression

# %% [markdown]
# <br>

# %%
#Transfer the continuous data into discrete data
#label=1:use the 0,1,2...to label the data
#label=0:use the quantile
def discret(contidata,n=5,label=1):
    disdata=np.array(contidata)
    div=list(np.arange(0,100,100/n))
    div.append(100)
    point=[np.percentile(contidata,div[x]) for x in range(n+1)]
    midpoint=[np.percentile(contidata,(div[x]+div[x+1])/2) for x in range(n)]
    if label==0:
            for i in range(n):
                disdata[(disdata>=point[i])&(disdata<=point[i+1])]=midpoint[i]   
    else:
            for i in range(n):
                disdata[(disdata>=point[i])&(disdata<=point[i+1])]=i   
    if label!=0:
        disdata=disdata.astype('int')
    return(disdata)

# %%
#delete some element from the range(N)
def drop(N,loc):
        temp=list(range(N))
        for i in loc:
            temp.remove(i)
        return(temp)

# %%
def Plotpred(X,y,classfier='linear'):   
    if classfier=='linear':   
        lm = LinearRegression()
        lm.fit(X,y)
        y_pred=lm.predict(X)
    ymin=y.min
    ymax=y.max
    plt.xlim(ymin,ymax)
    plt.ylim(ymin,ymax)
    plt.ylabel('Predicted')
    plt.xlabel('Measured')
    plt.scatter(y_con, y_pred)
    plt.plot(range(ymin,ymax),range(ymin,ymax),color='black',linewidth=3)
    plt.show()

# %%
#Plotting the confusion matrix
def confmat(y_true,y_pred):    
    confmat = confusion_matrix(y_true=y_true, y_pred=y_pred)
    fig, ax = plt.subplots(figsize=(4, 4))
    ax.matshow(confmat, cmap=plt.cm.Blues, alpha=0.3)
    for i in range(confmat.shape[0]):
        for j in range(confmat.shape[1]):
            ax.text(x=j, y=i, s=confmat[i, j], va='center', ha='center')
    plt.xlabel('Predicted label')
    plt.ylabel('True label')

    plt.tight_layout()
    plt.show()

# %%
from scipy import interp   
from sklearn.metrics import roc_curve, auc  
from sklearn.cross_validation import StratifiedKFold  
#plot the ROC curve  and calculate AUC
#using k-fold to the data to calculate the mean value
def ROC_CURVE(X,y,classifier):

    n_samples, n_features = X.shape  

    # Add noisy features  
    random_state = np.random.RandomState(0)  
    X = np.c_[X, random_state.randn(n_samples, 200 * n_features)]  
    # Classification and ROC analysis  

    cv = StratifiedKFold(y, n_folds=3)  

    #cv = list(StratifiedKFold(n_splits=3, 
                          #random_state=1).split(X_train, y_train))
    mean_tpr = 0.0  
    mean_fpr = np.linspace(0, 1, 100)  
    all_tpr = []  

    for i, (train, test) in enumerate(cv):  

        probas_ = classifier.fit(X[train], y[train]).predict_proba(X[test])  
        fpr, tpr, thresholds = roc_curve(y[test], probas_[:, 1])  
        mean_tpr += interp(mean_fpr, fpr, tpr)          
        mean_tpr[0] = 0.0                               
        roc_auc = auc(fpr, tpr)  
        plt.plot(fpr, tpr, lw=1, label='ROC fold %d (area = %0.2f)' % (i, roc_auc))  

    plt.plot([0, 1], [0, 1], '--', color=(0.6, 0.6, 0.6), label='Luck')  

    mean_tpr /= len(cv)                     
    mean_tpr[-1] = 1.0                      
    mean_auc = auc(mean_fpr, mean_tpr)      

    #print mean_fpr,len(mean_fpr)  
    #print mean_tpr  
    plt.plot(mean_fpr, mean_tpr, 'k--',  
             label='Mean ROC (area = %0.2f)' % mean_auc, lw=2)  

    plt.xlim([-0.05, 1.05])  
    plt.ylim([-0.05, 1.05])  
    plt.xlabel('False Positive Rate')  
    plt.ylabel('True Positive Rate')  
    plt.title('Receiver operating characteristic example')  
    plt.legend(loc="lower right")  
    plt.show()  
    print('Mean AUC: %.3f' % mean_auc)

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# # 3、Data Preprocessing

# %% [markdown]
# ## 3.1 Deal with nominal and ordinal features

# %%
#Set the path
import os
path='C:/Users/admin/Documents/GitHub/2017.M3.TQF-Forcasting-price-change-on-IPO-day'
os.chdir(path)

#read into data
ipodata=pd.read_csv('ipodata.csv',encoding='gbk',index_col=0)
#get the column and row size
[M,N]=ipodata.shape
#Mapping ordinal features
BACKDOOR_map={'否':0,'是':1}
ipodata['BACKDOOR']=ipodata['BACKDOOR'].map(BACKDOOR_map)
ipodata_nobank=ipodata.drop('IPO_LEADUNDR',1)
ipodata_nobank=pd.get_dummies(ipodata_nobank)

# %%
#Divide the features and dependent variable
ipodata_all=pd.get_dummies(ipodata)
X_all=ipodata_all.drop('iporeturn',1)
X_all=(X_all.drop('ipoturn',1)).values
X_all[:,1]=X_all[:,1]-2010

ModelData=ipodata_nobank
Y1_con=ModelData['iporeturn'].values
Y2_con=ModelData['ipoturn'].values
XX=ModelData.drop('iporeturn',1)
XX=(XX.drop('ipoturn',1)).values
XX[:,1]=XX[:,1]-2010
Y1=discret(Y1_con)
Y2=discret(Y2_con)
#normalization
from sklearn import preprocessing
scaler = preprocessing.StandardScaler()  
XX_std=XX.copy()
XX_std[:,2:6]= scaler.fit_transform(XX_std[:,2:6])
temp=drop(ModelData.shape[1],[6,7])
feat_labels_O = np.array((ModelData.columns[temp]))

# %%
#Divide the training and testing data
X_train, X_test, y1_train, y1_test = train_test_split(XX,Y1, test_size=0.3, random_state=0)
X_train_con, X_test_con, y1_train_con, y1_test_con = train_test_split(XX,Y1_con, test_size=0.3, random_state=0)

# %% [markdown]
# ## 3.2 Assessing feature importance with Random Forests

# %%
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
feat_labels_this=ipodata_all.columns[drop(ipodata_all.shape[1],[6,7])]
forest = RandomForestClassifier(n_estimators=500,
                                random_state=1)
forest.fit(X_all,Y1)
importances = forest.feature_importances_

indices = np.argsort(importances)[::-1]

for f in range(X_all.shape[1]):
    print("%2d) %-*s %f" % (f + 1, 30, 
                            feat_labels_this[indices[f]], 
                            importances[indices[f]]))
plt.title('Feature Importance for IPO return')
plt.bar(range(X_all.shape[1]), 
        importances[indices],
        align='center')

plt.xticks(range(X_all.shape[1]), 
           feat_labels_this[indices], rotation=90)
plt.xlim([-1, X_all.shape[1]])
plt.tight_layout()
#plt.savefig('images/04_09.png', dpi=300)
plt.show()
# Out:
#  1) IPO_PRICE                      0.154793
#  2) IPO_DATE                       0.127978
#  3) IPO_EXPENSE                    0.125553
#  4) IPO_AMOUNT                     0.110864
#  5) ipotime                        0.087282
#  6) INDUSTRY_GICS_工业               0.019452
#  7) INDUSTRY_GICS_信息技术             0.016680
#  8) INDUSTRY_GICS_可选消费             0.016575
#  9) INDUSTRY_GICS_材料               0.014913
# 10) MKT_中小企业板                      0.013782
# 11) IPO_LEADUNDR_广发证券股份有限公司        0.013319
# 12) IPO_LEADUNDR_国信证券股份有限公司        0.012973
# 13) MKT_创业板                        0.012574
# 14) MKT_主板                         0.012370
# 15) INDUSTRY_GICS_医疗保健             0.011910
# 16) IPO_LEADUNDR_招商证券股份有限公司        0.010658
# 17) IPO_LEADUNDR_中信证券股份有限公司        0.009212
# 18) IPO_LEADUNDR_华泰联合证券有限责任公司      0.009143
# 19) IPO_LEADUNDR_平安证券股份有限公司        0.009123
# 20) INDUSTRY_GICS_日常消费             0.009002
# 21) IPO_LEADUNDR_中信建投证券股份有限公司      0.008886
# 22) IPO_LEADUNDR_海通证券股份有限公司        0.008795
# 23) IPO_LEADUNDR_国金证券股份有限公司        0.008116
# 24) IPO_LEADUNDR_民生证券股份有限公司        0.007741
# 25) IPO_LEADUNDR_安信证券股份有限公司        0.007296
# 26) IPO_TYPE_上网定价                  0.007019
# 27) IPO_TYPE_网下询价,上网定价             0.006616
# 28) IPO_LEADUNDR_中国国际金融股份有限公司      0.005437
# 29) IPO_LEADUNDR_国泰君安证券股份有限公司      0.005316
# 30) IPO_LEADUNDR_兴业证券股份有限公司        0.005251
# 31) IPO_LEADUNDR_光大证券股份有限公司        0.005247
# 32) IPO_LEADUNDR_中国中投证券有限责任公司      0.004913
# 33) IPO_LEADUNDR_华林证券股份有限公司        0.004553
# 34) IPO_LEADUNDR_国元证券股份有限公司        0.004533
# 35) IPO_LEADUNDR_东吴证券股份有限公司        0.004505
# 36) IPO_LEADUNDR_中德证券有限责任公司        0.004479
# 37) IPO_LEADUNDR_中泰证券股份有限公司        0.004182
# 38) INDUSTRY_GICS_金融               0.004168
# 39) IPO_LEADUNDR_申万宏源证券承销保荐有限责任公司  0.003851
# 40) IPO_LEADUNDR_东北证券股份有限公司        0.003524
# 41) INDUSTRY_GICS_能源               0.003436
# 42) IPO_LEADUNDR_中银国际证券股份有限公司      0.003152
# 43) IPO_LEADUNDR_西南证券股份有限公司        0.003111
# 44) IPO_LEADUNDR_东方花旗证券有限公司        0.003058
# 45) IPO_LEADUNDR_长江证券承销保荐有限公司      0.003000
# 46) IPO_LEADUNDR_中国银河证券股份有限公司      0.002947
# 47) INDUSTRY_GICS_公用事业             0.002600
# 48) IPO_LEADUNDR_长城证券股份有限公司        0.002387
# 49) IPO_LEADUNDR_中航证券有限公司          0.002369
# 50) IPO_LEADUNDR_东海证券股份有限公司        0.002348
# 51) IPO_LEADUNDR_宏源证券股份有限公司        0.002322
# 52) BACKDOOR                       0.002304
# 53) IPO_LEADUNDR_西部证券股份有限公司        0.002269
# 54) IPO_LEADUNDR_国海证券股份有限公司        0.002130
# 55) IPO_LEADUNDR_华龙证券股份有限公司        0.002082
# 56) IPO_LEADUNDR_瑞银证券有限责任公司        0.002039
# 57) IPO_LEADUNDR_信达证券股份有限公司        0.001996
# 58) IPO_LEADUNDR_浙商证券股份有限公司        0.001968
# 59) IPO_LEADUNDR_华泰证券股份有限公司        0.001906
# 60) IPO_LEADUNDR_申万宏源证券有限公司        0.001906
# 61) IPO_LEADUNDR_东莞证券股份有限公司        0.001893
# 62) IPO_LEADUNDR_第一创业证券股份有限公司      0.001749
# 63) IPO_LEADUNDR_华西证券股份有限公司        0.001742
# 64) IPO_LEADUNDR_太平洋证券股份有限公司       0.001616
# 65) IPO_LEADUNDR_中国民族证券有限责任公司      0.001590
# 66) IPO_LEADUNDR_德邦证券股份有限公司        0.001566
# 67) IPO_LEADUNDR_国都证券股份有限公司        0.001479
# 68) IPO_LEADUNDR_东兴证券股份有限公司        0.001442
# 69) IPO_LEADUNDR_瑞信方正证券有限责任公司      0.001402
# 70) IPO_LEADUNDR_渤海证券股份有限公司        0.001225
# 71) IPO_LEADUNDR_新时代证券股份有限公司       0.001215
# 72) IPO_LEADUNDR_东方证券股份有限公司        0.001168
# 73) IPO_LEADUNDR_中天国富证券有限公司        0.001153
# 74) IPO_LEADUNDR_中原证券股份有限公司        0.001111
# 75) IPO_LEADUNDR_金元证券股份有限公司        0.001045
# 76) IPO_LEADUNDR_国融证券股份有限公司        0.000969
# 77) IPO_LEADUNDR_恒泰长财证券有限责任公司      0.000878
# 78) IPO_LEADUNDR_华融证券股份有限公司        0.000871
# 79) IPO_LEADUNDR_南京证券股份有限公司        0.000869
# 80) IPO_LEADUNDR_华英证券有限责任公司        0.000856
# 81) IPO_LEADUNDR_第一创业证券承销保荐有限责任公司  0.000853
# 82) IPO_LEADUNDR_广州证券股份有限公司        0.000840
# 83) IPO_LEADUNDR_万联证券股份有限公司        0.000808
# 84) IPO_LEADUNDR_红塔证券股份有限公司        0.000726
# 85) IPO_LEADUNDR_恒泰证券股份有限公司        0.000674
# 86) IPO_LEADUNDR_九州证券股份有限公司        0.000660
# 87) IPO_LEADUNDR_湘财证券股份有限公司        0.000514
# 88) IPO_TYPE_战略配售,网下询价,上网定价        0.000503
# 89) INDUSTRY_GICS_房地产              0.000503
# 90) IPO_LEADUNDR_爱建证券有限责任公司        0.000480
# 91) IPO_LEADUNDR_华安证券股份有限公司        0.000438
# 92) IPO_LEADUNDR_天风证券股份有限公司        0.000434
# 93) IPO_LEADUNDR_财通证券股份有限公司        0.000431
# 94) IPO_LEADUNDR_上海华信证券有限责任公司      0.000423
# 95) IPO_LEADUNDR_华创证券有限责任公司        0.000380
# 96) INDUSTRY_GICS_电信服务             0.000362
# 97) IPO_LEADUNDR_首创证券有限责任公司        0.000345
# 98) IPO_LEADUNDR_英大证券有限责任公司        0.000336
# 99) IPO_LEADUNDR_世纪证券有限责任公司        0.000334
# 100) IPO_LEADUNDR_宏信证券有限责任公司        0.000328
# 101) IPO_LEADUNDR_江海证券有限公司          0.000319
# 102) IPO_LEADUNDR_摩根士丹利华鑫证券有限责任公司   0.000304
# 103) IPO_LEADUNDR_国盛证券有限责任公司        0.000206
# 104) IPO_LEADUNDR_中山证券有限责任公司        0.000196
# 105) IPO_LEADUNDR_申港证券股份有限公司        0.000182
# 106) IPO_LEADUNDR_华福证券有限责任公司        0.000145
# 107) IPO_LEADUNDR_财富证券有限责任公司        0.000140
# 108) IPO_TYPE_网下询价,上网定价,定向配售        0.000131
# 109) IPO_TYPE_战略配售,网下询价,上网定价,比例换股   0.000094
# 110) IPO_LEADUNDR_国联证券股份有限公司        0.000078
# 111) IPO_LEADUNDR_华鑫证券有限责任公司        0.000073

# %% [markdown]
# ### As for the importance, we delete the features：investment bank、backdoor and IPO_TYPE

# %%
#temp=drop(ModelData.shape[1],[6,7])
#feat_labels = np.array((ModelData.columns[temp]))
keepf=np.array([1,2,3,4,5,17,18,19])
X=XX[:,keepf]
feat_labels = feat_labels_O [keepf]

#normalization
scaler = preprocessing.StandardScaler()  
X_std=X.copy()
X_std[:,2:6]= scaler.fit_transform(X_std[:,2:6])

# %%
X_train, X_test, y1_train, y1_test = train_test_split(X,Y1, test_size=0.3, random_state=1)
X_train_con, X_test_con, y1_train_con, y1_test_con = train_test_split(X,Y1_con, test_size=0.3, random_state=1)
X2_train_con, X2_test_con, y2_train_con, y2_test_con = train_test_split(X,Y2_con, test_size=0.3, random_state=1)
X_train_std, X_test_std, y1_train_std, y1_test_std = train_test_split(X_std,Y1, test_size=0.3, random_state=1)

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# # 4、ML Model

# %% [markdown]
# ## 4.1 Linear Regression

# %%
#There are many features, so we plot the real value and predicted value
from sklearn import linear_model

lm = linear_model.LinearRegression()
lm.fit(X_train_con,y1_train_con)
Y1_pred=lm.predict(X_test_con)
plt.xlim(-100, 200)
plt.ylim(-100, 200)
plt.ylabel('Predicted')
plt.xlabel('Measured')
plt.scatter(y1_test_con, Y1_pred)
plt.plot(range(-100, 200),range(-100, 200),color='black',linewidth=3)
plt.show()

# %%
#TEST the p_value and coef of every feature
import statsmodels.api as sm
est = sm.OLS(y1_train_con,X_train_con).fit()
est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.431
# Model:                            OLS   Adj. R-squared:                  0.428
# Method:                 Least Squares   F-statistic:                     137.5
# Date:                Mon, 07 May 2018   Prob (F-statistic):          9.71e-151
# Time:                        14:07:55   Log-Likelihood:                -6625.8
# No. Observations:                1279   AIC:                         1.327e+04
# Df Residuals:                    1271   BIC:                         1.331e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             9.9311      0.516     19.263      0.000       8.920      10.943
# x2            -0.9462      0.111     -8.515      0.000      -1.164      -0.728
# x3          9.923e-09   2.66e-09      3.726      0.000     4.7e-09    1.51e-08
# x4          -3.27e-07   5.23e-08     -6.253      0.000    -4.3e-07   -2.24e-07
# x5            -0.4155      0.234     -1.780      0.075      -0.874       0.043
# x6            79.3931      6.417     12.373      0.000      66.805      91.981
# x7            73.0646      7.330      9.968      0.000      58.684      87.445
# x8            82.0789      6.419     12.786      0.000      69.485      94.672
# ==============================================================================
# Omnibus:                      691.576   Durbin-Watson:                   2.040
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            23838.320
# Skew:                           1.881   Prob(JB):                         0.00
# Kurtosis:                      23.813   Cond. No.                     6.86e+09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.86e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
feat_labels
# Out:
# array(['IPO_DATE', 'IPO_PRICE', 'IPO_AMOUNT', 'IPO_EXPENSE', 'ipotime',
#        'MKT_中小企业板', 'MKT_主板', 'MKT_创业板'], dtype=object)

# %% [markdown]
# #### Most variables are significant by their P-value
# #### The ipo-price and ipo-time have negative impact to the return.
# #### The stocks on Main-board are tend to have smaller return

# %%
#use the original all data to test and figure out what impact of they have
import statsmodels.api as sm
es = sm.OLS(Y1_con,X_all).fit()
es.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.487
# Model:                            OLS   Adj. R-squared:                  0.455
# Method:                 Least Squares   F-statistic:                     15.27
# Date:                Mon, 07 May 2018   Prob (F-statistic):          1.67e-180
# Time:                        14:08:02   Log-Likelihood:                -9342.7
# No. Observations:                1828   AIC:                         1.890e+04
# Df Residuals:                    1720   BIC:                         1.950e+04
# Df Model:                         107
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            19.4135     11.084      1.752      0.080      -2.326      41.153
# x2             9.5739      0.478     20.042      0.000       8.637      10.511
# x3            -0.8560      0.095     -9.007      0.000      -1.042      -0.670
# x4          1.418e-08   2.66e-09      5.339      0.000    8.97e-09    1.94e-08
# x5         -3.467e-07    4.7e-08     -7.374      0.000   -4.39e-07   -2.54e-07
# x6            -0.2956      0.188     -1.573      0.116      -0.664       0.073
# x7            12.7749      4.363      2.928      0.003       4.217      21.332
# x8            22.5506      9.946      2.267      0.024       3.042      42.059
# x9            16.8479      5.000      3.369      0.001       7.041      26.655
# x10            6.3334      4.456      1.421      0.155      -2.406      15.073
# x11           10.2491      4.099      2.500      0.012       2.210      18.289
# x12          -16.6419     22.630     -0.735      0.462     -61.026      27.743
# x13            9.7365      5.570      1.748      0.081      -1.189      20.662
# x14           11.4761      4.494      2.553      0.011       2.661      20.291
# x15           26.4344     27.396      0.965      0.335     -27.298      80.167
# x16            8.6169      8.840      0.975      0.330      -8.722      25.955
# x17           -6.6010      8.428     -0.783      0.434     -23.131       9.929
# x18           34.7438      7.968      4.360      0.000      19.115      50.373
# x19           30.8319      8.164      3.777      0.000      14.820      46.844
# x20           36.2013      7.980      4.537      0.000      20.550      51.852
# x21           31.3723     18.465      1.699      0.089      -4.843      67.588
# x22            6.1246     23.810      0.257      0.797     -40.575      52.824
# x23           -1.6548     29.055     -0.057      0.955     -58.641      55.331
# x24           -8.5556     13.170     -0.650      0.516     -34.386      17.275
# x25            3.4244      9.880      0.347      0.729     -15.953      22.802
# x26           -5.6228      8.041     -0.699      0.484     -21.393      10.147
# x27            4.0500      9.456      0.428      0.668     -14.496      22.596
# x28          -31.8056     14.660     -2.170      0.030     -60.558      -3.053
# x29            1.7882     10.482      0.171      0.865     -18.770      22.347
# x30          -17.8088     12.022     -1.481      0.139     -41.388       5.770
# x31            2.9206      5.172      0.565      0.572      -7.224      13.065
# x32            1.9129      4.778      0.400      0.689      -7.458      11.283
# x33           10.1998     16.953      0.602      0.547     -23.050      43.450
# x34            7.8257      8.047      0.973      0.331      -7.957      23.608
# x35           22.8480      7.129      3.205      0.001       8.866      36.830
# x36            1.5553     13.887      0.112      0.911     -25.682      28.792
# x37            8.0295     10.231      0.785      0.433     -12.038      28.097
# x38           -9.8184     18.476     -0.531      0.595     -46.056      26.419
# x39           30.7445     41.018      0.750      0.454     -49.706     111.195
# x40            3.6563      7.798      0.469      0.639     -11.639      18.952
# x41            4.6728      7.760      0.602      0.547     -10.546      19.892
# x42            3.9503     11.553      0.342      0.732     -18.709      26.610
# x43           -7.5163     10.231     -0.735      0.463     -27.582      12.549
# x44          -40.0905     29.120     -1.377      0.169     -97.205      17.024
# x45           11.7118     12.543      0.934      0.351     -12.890      36.314
# x46           -1.5803      6.919     -0.228      0.819     -15.150      11.990
# x47            0.7486      7.093      0.106      0.916     -13.162      14.660
# x48           25.1719     23.841      1.056      0.291     -21.588      71.932
# x49            6.1173     29.050      0.211      0.833     -50.860      63.095
# x50           20.9082      8.302      2.519      0.012       4.626      37.191
# x51           -2.3328      5.090     -0.458      0.647     -12.316       7.650
# x52          -11.6207     11.661     -0.997      0.319     -34.492      11.251
# x53           21.0024     41.059      0.512      0.609     -59.528     101.533
# x54           -9.2179     23.825     -0.387      0.699     -55.946      37.510
# x55           26.6561     18.615      1.432      0.152      -9.854      63.166
# x56           -3.4844     12.565     -0.277      0.782     -28.129      21.160
# x57          -20.5023     41.900     -0.489      0.625    -102.683      61.678
# x58           11.6366     11.597      1.003      0.316     -11.110      34.383
# x59            8.8604     18.500      0.479      0.632     -27.425      45.146
# x60           -5.1706      3.920     -1.319      0.187     -12.860       2.518
# x61           -5.7525      7.766     -0.741      0.459     -20.984       9.479
# x62          -11.4567      6.879     -1.665      0.096     -24.949       2.036
# x63           19.0140     10.783      1.763      0.078      -2.134      40.162
# x64          -45.9959     29.036     -1.584      0.113    -102.945      10.953
# x65          -47.7157     41.021     -1.163      0.245    -128.172      32.740
# x66            1.1814     16.868      0.070      0.944     -31.902      34.265
# x67          -13.8746     13.180     -1.053      0.293     -39.725      11.975
# x68            2.4185      5.554      0.435      0.663      -8.475      13.312
# x69           20.0294     23.947      0.836      0.403     -26.939      66.998
# x70          -12.4031     12.589     -0.985      0.325     -37.094      12.288
# x71           -1.0759      5.695     -0.189      0.850     -12.245      10.094
# x72            7.9375     29.174      0.272      0.786     -49.282      65.157
# x73          -14.7629     10.517     -1.404      0.161     -35.390       5.864
# x74            1.9584      4.687      0.418      0.676      -7.235      11.151
# x75           -3.2880      4.241     -0.775      0.438     -11.607       5.031
# x76           20.0217     16.874      1.187      0.236     -13.073      53.117
# x77           16.2211     13.133      1.235      0.217      -9.538      41.980
# x78          -29.9824     23.735     -1.263      0.207     -76.535      16.571
# x79            7.8250     18.467      0.424      0.672     -28.396      44.046
# x80           11.0923      4.755      2.333      0.020       1.765      20.419
# x81           33.1776     29.051      1.142      0.254     -23.802      90.157
# x82           -4.6013     16.922     -0.272      0.786     -37.792      28.589
# x83            0.3342      5.807      0.058      0.954     -11.055      11.724
# x84           22.2554     29.079      0.765      0.444     -34.778      79.289
# x85          -16.4734     13.205     -1.248      0.212     -42.372       9.425
# x86           -2.6265      5.024     -0.523      0.601     -12.481       7.228
# x87          -13.7289     15.631     -0.878      0.380     -44.387      16.929
# x88            8.4628     23.755      0.356      0.722     -38.129      55.055
# x89           24.6575     23.749      1.038      0.299     -21.922      71.237
# x90            4.5545     18.528      0.246      0.806     -31.785      40.894
# x91           10.2669     11.448      0.897      0.370     -12.186      32.720
# x92           15.4666      7.937      1.949      0.052      -0.101      31.035
# x93           -1.7794     14.105     -0.126      0.900     -29.443      25.884
# x94          -26.1844     41.131     -0.637      0.524    -106.857      54.489
# x95          -18.4002     18.585     -0.990      0.322     -54.852      18.052
# x96            8.8426     13.906      0.636      0.525     -18.432      36.117
# x97          -22.3558     20.631     -1.084      0.279     -62.820      18.108
# x98           27.6409     29.057      0.951      0.342     -29.350      84.632
# x99            3.2726      8.634      0.379      0.705     -13.662      20.207
# x100          -7.4501     10.511     -0.709      0.479     -28.066      13.166
# x101          25.4010     41.071      0.618      0.536     -55.153     105.955
# x102           8.2137     23.793      0.345      0.730     -38.454      54.881
# x103          -7.4734     16.862     -0.443      0.658     -40.546      25.599
# x104          -5.9527     10.820     -0.550      0.582     -27.173      15.268
# x105          12.7865      9.724      1.315      0.189      -6.285      31.858
# x106           0.9716     23.777      0.041      0.967     -45.664      47.607
# x107          38.5886      9.989      3.863      0.000      18.997      58.180
# x108         -12.4301     24.562     -0.506      0.613     -60.604      35.744
# x109          18.4094     37.015      0.497      0.619     -54.189      91.008
# x110          30.6553      9.424      3.253      0.001      12.172      49.138
# x111          26.5538     36.607      0.725      0.468     -45.245      98.352
# ==============================================================================
# Omnibus:                      833.541   Durbin-Watson:                   1.427
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            25888.362
# Skew:                           1.515   Prob(JB):                         0.00
# Kurtosis:                      21.185   Cond. No.                     1.93e+24
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.08e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# #### The back door、industry and ipo-type are not significant, which is consistent with the former result.
# #### Some industries tends to have significant higher return: Public utility,health care, Consumer Discretionary,energy，which are most emerging industries.
# #### Investment banks like 中原证券 中国银河证券 首创证券 华安证券 兴业证券 have higher return, which means these investment banks tend to undervalue the stocks

# %% [markdown]
# ### Using PCA to the data

# %%
from sklearn.decomposition import PCA
pca = PCA()
X_pca = pca.fit_transform(X_std)
#plot the cummulated explained variance
lengg=len(pca.explained_variance_ratio_)
plt.bar(range(lengg), pca.explained_variance_ratio_, alpha=0.5, align='center')
plt.step(range(lengg), np.cumsum(pca.explained_variance_ratio_), where='mid')
plt.ylabel('Explained variance ratio')
plt.xlabel('Principal components')
plt.show()

# %%
PCAX=X_pca[:,:2]
est2 = sm.OLS(Y1_con,PCAX).fit()
est2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.152
# Model:                            OLS   Adj. R-squared:                  0.151
# Method:                 Least Squares   F-statistic:                     163.8
# Date:                Mon, 07 May 2018   Prob (F-statistic):           3.72e-66
# Time:                        14:11:50   Log-Likelihood:                -10719.
# No. Observations:                1828   AIC:                         2.144e+04
# Df Residuals:                    1826   BIC:                         2.145e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -1.9657      0.147    -13.331      0.000      -2.255      -1.677
# x2             9.6795      0.791     12.243      0.000       8.129      11.230
# ==============================================================================
# Omnibus:                      729.320   Durbin-Watson:                   0.350
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            19198.891
# Skew:                           1.287   Prob(JB):                         0.00
# Kurtosis:                      18.666   Cond. No.                         5.36
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# #### PCA doesn't improve the regression result.
# #### We will not use PCA in the later model.

# %% [markdown]
# <br>

# %% [markdown]
# ## 4.2 Decision Tree

# %%
tree = DecisionTreeClassifier(criterion='gini', 
                              max_depth=8, 
                              random_state=1)
tree.fit(X_train, y1_train)
y1_pred=tree.predict(X_test)

# %%
confmat(y_true=y1_test, y_pred=y1_pred)

# %%
y01_train=y1_train.copy()
y01_train[y01_train<=2]=0
y01_train[y01_train>2]=1
tree.fit(X_train, y01_train)
ROC_CURVE(X_train,y01_train,tree)
# Out:
# Mean AUC: 0.644

# %% [markdown]
# <br>

# %% [markdown]
# ## 4.3 Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier  
rdf = RandomForestClassifier(n_estimators=10)  
rdf = rdf.fit(X_train, y1_train)  
y1_pred=rdf.predict(X_test)
confmat(y_true=y1_test, y_pred=y1_pred)

# %%
rdf = RandomForestClassifier(n_estimators=10)  
rdf = rdf.fit(X_train, y01_train)  
ROC_CURVE(X_train,y01_train,rdf)
# Out:
# Mean AUC: 0.677

# %% [markdown]
# <br>

# %% [markdown]
# ## 4.4 Logistic Regression

# %%
lgt=LogisticRegression()
lgt.fit(X_train,y01_train)
ROC_CURVE(X_train,y01_train,lgt)
# Out:
# Mean AUC: 0.669

# %% [markdown]
# <br>

# %% [markdown]
# ## 4.5 KNN

# %%
from sklearn import neighbors   
  
knn = neighbors.KNeighborsClassifier()    
knn.fit(X_train,y1_train) 
y1_pred=knn.predict(X_test)
confmat(y_true=y1_test, y_pred=y1_pred)

# %%
knn = neighbors.KNeighborsClassifier()    
knn.fit(X_train,y01_train) 
ROC_CURVE(X_train,y01_train,knn)
# Out:
# Mean AUC: 0.603

# %% [markdown]
# ## 4.6 SVM

# %%
svm = SVC(probability=True)
svm.fit(X_train_std,y1_train_std) 
y1_pred=svm.predict(X_test_std)
confmat(y_true=y1_test_std, y_pred=y1_pred)

# %%
y01_train_std=y1_train_std.copy()
y01_train_std[y01_train_std<=2]=0
y01_train_std[y01_train_std>2]=1
#using the normalized data to SVM
svm = SVC(probability=True)
svm.fit(X_train_std,y01_train_std) 
ROC_CURVE(X_train_std,y01_train_std,svm)
# Out:
# Mean AUC: 0.863

# %% [markdown]
# ## 4.7 Multi-layer Perceptron

# %%
from sklearn.neural_network import MLPClassifier

nn = MLPClassifier(solver='lbfgs', alpha=1e-5,hidden_layer_sizes=(4, 2), random_state=1)
nn.fit(X_train_std,y1_train_std)                         
y1_pred=nn.predict(X_test_std)
confmat(y_true=y1_test_std, y_pred=y1_pred)

# %%
nn = MLPClassifier(solver='lbfgs', alpha=1e-5,hidden_layer_sizes=(4, 2), random_state=1)
nn.fit(X_train_std,y1_train_std)   
ROC_CURVE(X_train_std,y01_train_std,nn)
# Out:
# Mean AUC: 0.772

# %% [markdown]
# <br>

# %% [markdown]
# # 5、Summary

# %% [markdown]
# ### 5.1 The relationship about the features and dependent variable

# %% [markdown]
# ##### (1) Using the randon forest to test the importance of variables and find that backdoor、IPO-type、Investment Banks are more unimpotant.
# ##### (2) IPO_DATE，IPO_PRICE，IPO_AMOUNT，IPO_EXPENSE，and IPO_board have more significant impact to the return
# ##### (3) The IPO_PRICE and IPO_TIME have negative impact to the return.
# ##### (4) The stocks on Main-board are tend to have smaller return
# ##### (5) The return are going to be higher year after year. A share investors all believe the return on ipo day is high, more and more investors are trend to buy the 'new stocks'
# #### (6) Some industries tends to have significant higher return: Public utility,health care, Consumer Discretionary,energy. Most these industries are emerging industry
# #### (7) Investment banks like 中原证券 中国银河证券 首创证券 华安证券 兴业证券 have higher return
# #### which means these investment banks tend to undervalue the stocks.

# %% [markdown]
# ### 5.2 The forecasting result of the ML model

# %% [markdown]
# ##### (1) PCA has no improvement to this data
# ##### (2) By using K-fold and calculating the mean auc, all the model has mean auc above 0.6
# #####      Neural network&svm has significant better result  0.772 and 0.863
